# %% [markdown]
# - go to databases
# - create a new database
# -

# %%
CREATE TABLE Department(
  id INT PRIMARY KEY,
  name VARCHAR(50),
  university VARCHAR(50),
  Head_Dept VARCHAR(50),
  year_starting INT
); 

CREATE TABLE Employees(
  id INT PRIMARY KEY,
  name VARCHAR(50),
  department_id INT,
  salary INT,
  city VARCHAR(50),
  hiring_year INT,
  FOREIGN KEY (department_id) REFERENCES Department(id)
  )

  ALTER TABLE Employees
  ADD CONSTRAINT salary_fk FOREIGN KEY (salary) REFERENCES Department(teacher_salary)

 --- remove the constraint
 -- update the constraint 
 

  ALTER TABLE Employees
  ALTER COLUMN name SET NOT NULL

  SELECT * FROM department
  SELECT * FROM employees

  INSERT INTO department (id,name,university,head_dept,year_starting) 
  VALUES (1, 'Mathematics', 'California University', 'Ibrahim', 2020),
  (2, 'Physics', 'California University', 'Mell', 2020),
  (3, 'Literature', 'California University', 'Hazirah', 2020);

  INSERT INTO department (id,name,university,head_dept,year_starting) 
  VALUES (4, 'Computer_Science', 'MIT', 'Idrees', 2020)

  UPDATE Department
  SET university =  'California University'
  WHERE id = 4

  UPDATE Department
  SET teacher_salary =  50000
  WHERE id IN (1,2,3,4)

  UPDATE Department
  SET name =  'Computer Science'
  WHERE id = 4

  -- structure of the table?
  -- remove columns? rows? DROP and DELETE
  -- list id as the primary key??

ALTER TABLE department
ALTER COLUMN teacher_salary TYPE INT



INSERT INTO employees (id,name,department_id,salary,city, hiring_year) 
  VALUES (1, 'Ibrahim', 4,50000, 'KL', 2020),
  (2, 'Hazirah', 3, 50000,'KL', 2021),
  (3, 'Mell', 2, 50000,'KL', 2023),
  (4, 'Aiysah', 4, 50000,'KL', 2020),
  (5, 'Nazihah', 2, 50000,'KL', 2025),
  (6, 'Amin', 1, 50000,'KL', 2022),
  (7, 'Nazri', 1, 50000,'KL', 2021);


SELECT Department.Name, Department.head_dept, employees.name, employees.salary
FROM Department
INNER JOIN Employees ON Department.id = Employees.department_id


  create table x(
id int primary key,
x text
)
insert into x (id,x) Values (1,'x1'),(2,'x2'),(3,'x3');

create table y(
id int primary key,
y text
)

insert into y (id,y) Values (1,'y1'),(2,'y2'),(3,'y3'),(4,'y4'),(5,'y6'),(6,'y6');

select * from x
select * from y

drop table y

Delete from y
where id = 3


select * from x

select * from y

SELECT x.x, y.y
FROM x
INNER JOIN y ON x.id = y.id

SELECT x.x, y.y
FROM x
LEFT JOIN y ON x.id = y.id

SELECT x.x, y.y
FROM x
RIGHT JOIN y ON x.id = y.id


SELECT x.x, y.y
FROM x
FULL OUTER JOIN y ON x.id = y.id
